# %% [markdown]
# # 📄 Project Summary: Exploratory Data Analysis on CardioGoodFitness Dataset
#
# ## 🔎 Project Overview
# This project focuses on performing **Exploratory Data Analysis (EDA)** on the **CardioGoodFitness** dataset, which contains customer data collected by a fitness equipment company. The primary objective of this analysis is to understand customer behavior, purchasing patterns, and demographic insights that influence product preferences.
#
# ## 📊 Dataset Description
# The **CardioGoodFitness** dataset includes information about customers who have purchased treadmills from the company. The dataset contains variables such as:
# - **Product** - Type of treadmill purchased (TM195, TM498, TM798)
# - **Age** - Customer's age
# - **Gender** - Male or Female
# - **Education** - Years of education completed
# - **Marital Status** - Single or Married
# - **Usage** - Average number of times the customer uses the treadmill per week
# - **Fitness** - Self-reported fitness level (scale from 1 to 5)
# - **Income** - Annual income of the customer
# - **Miles** - Average weekly miles run on the treadmill
#
# ## 🎯 Objectives
# - Understand the **demographic profile** of customers.
# - Analyze **product preferences** based on gender, age, and income.
# - Study the relationship between **income levels** and product choice.
# - Identify **patterns in fitness levels, treadmill usage, and weekly miles**.
# - Use **colorful and visually appealing graphs** to make insights clear and engaging.
#
# ## 🔬 Key Analyses Performed
# - **Customer Demographics Analysis**: Gender distribution, age distribution, income segmentation.
# - **Product Preference Insights**: Comparing product choices across income groups, fitness levels, and genders.
# - **Behavioral Insights**: Weekly usage and miles covered across product types.
# - **Correlation Analysis**: Heatmap to study relationships between numerical variables like age, income, fitness, and miles.
# - **Advanced Visualizations**: Combination of **pie charts, bar charts, violin plots, scatter plots, and heatmaps** using **Seaborn and Matplotlib**, with a focus on using **vibrant and colorful visuals**.
#
# ## 🚀 Outcome
# This comprehensive analysis helps the company:
# - **Identify target customer segments** for each product.
# - **Understand what influences treadmill purchases** (age, income, fitness level, etc.).
# - **Develop data-driven marketing strategies** for different customer groups.
#
# ## 🌈 Why This Project Stands Out
# - Focus on **both analytical depth and visual appeal**.
# - Use of **colorful plots** to enhance **clarity** and **engagement**.
# - Easy-to-understand **insights**, suitable for both technical and non-technical audiences.

# %% [markdown]
# # 1️⃣ Import Libraries and Load Data

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# #### (1.1)  Load dataset using (df = pd.read_csv(r"link of your csv.file")
# - in the 'df' place you can write any variable name, like anything of name,<br><br>
# - this line denotes ---- "sns.set(style="whitegrid", palette="bright")" This line will be used for output style and some changes in text style, as well as the colors of output data.<br><br>
# - After that, this line: print(df.head()) defines the output of our data in that head and will give the first five rows of our data.

# %%
# Load dataset
df = pd.read_csv(r"E:\IT Vedant\python\EDA Project\CardioGoodFitness.csv")
# Set Seaborn style and color palette for beauty
sns.set(style="whitegrid", palette="bright")

# Show first few rows
print(df.head())
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# #### (1.2) if we want data from back side we will use --- "df.tail()"

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# #### (1.3) if we want any specific rows
# - in "df.head(10)" in 10 place we want write for specific lines

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %% [markdown]
# #### (1.4) How to check our "data size"

# %%
print('Row and column number of data: {}'.format(df.shape))
df.shape
# Out:
# Row and column number of data: (180, 9)
# (180, 9)

# %% [markdown]
# # 2️⃣ Basic Information and Summary

# %% [markdown]
# #### (2.1) Basic Info (Data type and content)

# %%
print("Dataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB
# None

# %% [markdown]
# #### (2.2)  Summary Statistics

# %%
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# #### (2.3)  Check missing data values

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
pd.pivot_table(df, index=['Product', 'Gender'], columns = ['MaritalStatus'], aggfunc=len)
# Out:
#                      Age        Education          Fitness           Income  \
# MaritalStatus  Partnered Single Partnered Single Partnered Single Partnered
# Product Gender
# TM195   Female        27     13        27     13        27     13        27
#         Male          21     19        21     19        21     19        21
# TM498   Female        15     14        15     14        15     14        15
#         Male          21     10        21     10        21     10        21
# TM798   Female         4      3         4      3         4      3         4
#         Male          19     14        19     14        19     14        19
#
#                           Miles            Usage
# MaritalStatus  Single Partnered Single Partnered Single
# Product Gender
# TM195   Female     13        27     13        27     13
#         Male       19        21     19        21     19
# TM498   Female     14        15     14        15     14
# ...

# %% [markdown]
# #### (2.4)Average of miles for combination of given variables

# %%
pd.pivot_table(df, 'Miles',index=['Product', 'Gender'], columns = ['MaritalStatus'])
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %% [markdown]
# #### (2.4)summary of distribution for relevant variables on histogram

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Education'}>],
#        [<Axes: title={'center': 'Usage'}>,
#         <Axes: title={'center': 'Fitness'}>],
#        [<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Miles'}>]], dtype=object)

# %% [markdown]
# # 3️⃣ Gender Distribution (Colorful Pie Chart)

# %%
plt.figure(figsize=(6,3))
colors = ['#ff9999','#66b3ff']
df['Gender'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=colors, explode=[0.03,0.03])
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# # 4️⃣ Product Preference by Gender (Colorful Count Plot)

# %%
plt.figure(figsize=(7,3.5))
sns.countplot(data=df, x='Product', hue='Gender', palette='Set2')
plt.title('Product Preference by Gender')
plt.show()

# %% [markdown]
# # 5️⃣ Age Distribution (Colorful Histogram)

# %%
plt.figure(figsize=(6,3))
sns.histplot(df['Age'], kde=True, color='purple')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# # 6️⃣ Income vs Product (Colorful Box Plot)

# %%
plt.figure(figsize=(7,3.5))
sns.boxplot(data=df, x='Product', y='Income', hue='Product', palette='Spectral', legend=False)
plt.title('Income Distribution Across Products')
plt.show()

# %% [markdown]
# # 7️⃣ Fitness Level vs Product (Colorful Count Plot)

# %%
plt.figure(figsize=(6,3))
sns.countplot(data=df, x='Fitness', hue='Product', palette='coolwarm')
plt.title('Fitness Level across Products')
plt.show()

# %% [markdown]
# # 8️⃣ Marital Status Distribution (Colorful Pie Chart)

# %%
colors = ['#ffcc99', '#99ff99']
plt.figure(figsize=(4,2))
df['MaritalStatus'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140, colors=colors, explode=[0.05, 0.05])
plt.title('Marital Status Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# # 9️⃣ Usage vs Product (Violin Plot - Beautiful)

# %%
plt.figure(figsize=(7,3.5))
sns.violinplot(data=df, x='Product', y='Income', hue='Product', palette='Spectral', legend=False)
plt.title('Weekly Usage by Product')
plt.show()

# %% [markdown]
# # 🔟 Correlation Heatmap (Colorful Heatmap)

# %%
plt.figure(figsize=(8,4))

# Select only numeric columns
numeric_df = df.select_dtypes(include=[np.number])

# Create heatmap
sns.heatmap(numeric_df.corr(), annot=True, cmap='YlGnBu', fmt=".2f")

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # 1️⃣1️⃣ Pairplot for All Numeric Features (Pairplot - Full Color Explosion 💥)

# %%
plt.figure(figsize=(8,4))
sns.pairplot(df, hue="Product", palette="husl")
plt.show()

# %% [markdown]
# # 1️⃣2️⃣ Interactive Plotly Chart (Income vs Miles)

# %%
fig = px.scatter(df, x='Income', y='Miles', color='Product', size='Age', hover_data=['Gender', 'Education'])
fig.update_layout(title="Income vs Miles with Product Color & Age Size", title_x=0.5)
fig.show()
